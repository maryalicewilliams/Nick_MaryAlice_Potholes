# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
incomeblocksgdf = gpd.read_file('acs2019_5yr_B19013_15000US060014053011.geojson')

# %%
incomeblocksgdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             338 non-null    object
#  1   name              338 non-null    object
#  2   B19013001         321 non-null    float64
#  3   B19013001, Error  320 non-null    float64
#  4   geometry          338 non-null    geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 13.3+ KB

# %%
incomeblocksgdf.head()
# Out:
#                  geoid                        name  B19013001  \
# 0  15000US060014001001  Block Group 1, Alameda, CA   219861.0
# 1  15000US060014002001  Block Group 1, Alameda, CA   237500.0
# 2  15000US060014002002  Block Group 2, Alameda, CA   162583.0
# 3  15000US060014003001  Block Group 1, Alameda, CA   183482.0
# 4  15000US060014003002  Block Group 2, Alameda, CA   101736.0
#
#    B19013001, Error                                           geometry
# 0           17887.0  MULTIPOLYGON (((-122.24692 37.88544, -122.2466...
# 1           23842.0  MULTIPOLYGON (((-122.25508 37.84607, -122.2542...
# 2           63106.0  MULTIPOLYGON (((-122.25792 37.84261, -122.2577...
# 3           79006.0  MULTIPOLYGON (((-122.25186 37.84475, -122.2517...
# 4           36064.0  MULTIPOLYGON (((-122.26230 37.83786, -122.2622...

# %%
incomeblocksgdf
# Out:
#                    geoid                        name  B19013001  \
# 0    15000US060014001001  Block Group 1, Alameda, CA   219861.0
# 1    15000US060014002001  Block Group 1, Alameda, CA   237500.0
# 2    15000US060014002002  Block Group 2, Alameda, CA   162583.0
# 3    15000US060014003001  Block Group 1, Alameda, CA   183482.0
# 4    15000US060014003002  Block Group 2, Alameda, CA   101736.0
# ..                   ...                         ...        ...
# 333  15000US060019819001  Block Group 1, Alameda, CA   171563.0
# 334  15000US060019820001  Block Group 1, Alameda, CA   128750.0
# 335  15000US060019832001  Block Group 1, Alameda, CA   165909.0
# 336  15000US060019900000  Block Group 0, Alameda, CA        NaN
# 337       16000US0653000                 Oakland, CA    73692.0
#
#      B19013001, Error                                           geometry
# 0             17887.0  MULTIPOLYGON (((-122.24692 37.88544, -122.2466...
# ...

# %%
incomeblocksgdf = incomeblocksgdf.drop(337)

# %%
incomeblocksgdf.sort_values(by='B19013001', ascending=False)
# Out:
#                    geoid                        name  B19013001  \
# 130  15000US060014051002  Block Group 2, Alameda, CA   250001.0
# 1    15000US060014002001  Block Group 1, Alameda, CA   237500.0
# 101  15000US060014042002  Block Group 2, Alameda, CA   235750.0
# 108  15000US060014044003  Block Group 3, Alameda, CA   232105.0
# 100  15000US060014042001  Block Group 1, Alameda, CA   229773.0
# ..                   ...                         ...        ...
# 276  15000US060014087005  Block Group 5, Alameda, CA        NaN
# 285  15000US060014090002  Block Group 2, Alameda, CA        NaN
# 287  15000US060014090004  Block Group 4, Alameda, CA        NaN
# 320  15000US060014100003  Block Group 3, Alameda, CA        NaN
# 336  15000US060019900000  Block Group 0, Alameda, CA        NaN
#
#      B19013001, Error                                           geometry
# 130               NaN  MULTIPOLYGON (((-122.23557 37.80945, -122.2350...
# ...

# %%
incomeblocksgdf19 = incomeblocksgdf.dropna()

# %%
incomeblocksgdf19
# Out:
#                    geoid                        name  B19013001  \
# 0    15000US060014001001  Block Group 1, Alameda, CA   219861.0
# 1    15000US060014002001  Block Group 1, Alameda, CA   237500.0
# 2    15000US060014002002  Block Group 2, Alameda, CA   162583.0
# 3    15000US060014003001  Block Group 1, Alameda, CA   183482.0
# 4    15000US060014003002  Block Group 2, Alameda, CA   101736.0
# ..                   ...                         ...        ...
# 331  15000US060014104003  Block Group 3, Alameda, CA    61947.0
# 332  15000US060014105001  Block Group 1, Alameda, CA    31151.0
# 333  15000US060019819001  Block Group 1, Alameda, CA   171563.0
# 334  15000US060019820001  Block Group 1, Alameda, CA   128750.0
# 335  15000US060019832001  Block Group 1, Alameda, CA   165909.0
#
#      B19013001, Error                                           geometry
# 0             17887.0  MULTIPOLYGON (((-122.24692 37.88544, -122.2466...
# ...

# %%
incomeblocksgdf19 = incomeblocksgdf19[['geoid','name','B19013001','geometry']]

# %%
incomeblocksgdf19.columns = ['geoid','block name','median income','geometry']

# %%
incomeblocksgdf19
# Out:
#                    geoid                  block name  median income  \
# 0    15000US060014001001  Block Group 1, Alameda, CA       219861.0
# 1    15000US060014002001  Block Group 1, Alameda, CA       237500.0
# 2    15000US060014002002  Block Group 2, Alameda, CA       162583.0
# 3    15000US060014003001  Block Group 1, Alameda, CA       183482.0
# 4    15000US060014003002  Block Group 2, Alameda, CA       101736.0
# ..                   ...                         ...            ...
# 331  15000US060014104003  Block Group 3, Alameda, CA        61947.0
# 332  15000US060014105001  Block Group 1, Alameda, CA        31151.0
# 333  15000US060019819001  Block Group 1, Alameda, CA       171563.0
# 334  15000US060019820001  Block Group 1, Alameda, CA       128750.0
# 335  15000US060019832001  Block Group 1, Alameda, CA       165909.0
#
#                                               geometry
# 0    MULTIPOLYGON (((-122.24692 37.88544, -122.2466...
# ...

# %%
incomeblocksgdf19.plot()
# Out:
# <AxesSubplot:>

# %%
incomeblocksgdf19.to_file("Income Blocks.geojson", driver='GeoJSON')
